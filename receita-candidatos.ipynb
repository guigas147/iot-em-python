# %% [markdown]
# ### Dicionario dos dados da tabela

# %% [markdown]
# | Nome                           | Tipo No BigQuery | Descrição                                                                  | Cobertura Temporal | Unidade De Medida | Contém Dados Sensíveis (LGPD) |
# |--------------------------------|------------------|----------------------------------------------------------------------------|--------------------|-------------------|-------------------------------|
# | categoria_vacina               | STRING           | Categoria                                                                  | 2020 - 2022        | Não listado       | Não listado                   |
# | cep_endereco_paciente          | STRING           | CEP do Endereço (5 dígitos para anonimizado e 7 dígitos para identificado) | 2020 - 2022        | Não listado       | Não listado                   |
# | codigo_vacina                  | STRING           | Código da vacina                                                           | 2020 - 2022        | Não listado       | Não listado                   |
# | data_aplicacao_vacina          | DATE             | Data de aplicação                                                          | 2020 - 2022        | Não listado       | Não listado                   |
# | data_importacao_rnds           | DATE             | Data de importação                                                         | 2020 - 2022        | Não listado       | Não listado                   |
# | data_nascimento_paciente       | DATE             | Data de nascimento                                                         | 2020 - 2022        | Não listado       | Não listado                   |
# | dose_vacina                    | STRING           | Dose                                                                       | 2020 - 2022        | Não listado       | Não listado                   |
# | grupo_atendimento_vacina       | STRING           | Grupo de atendimento                                                       | 2020 - 2022        | Não listado       | Não listado                   |
# | idade_paciente                 | INT64            | Idade (ano)                                                                | 2020 - 2022        | Não listado       | Não listado                   |
# | id_documento                   | STRING           | ID Documento                                                               | 2020 - 2022        | Não listado       | Não listado                   |
# | id_estabelecimento             | STRING           | ID Estabelecimento - CNES                                                  | 2020 - 2022        | Não listado       | Não listado                   |
# | id_municipio_endereco_paciente | STRING           | ID Município do Endereço - IBGE 7 Dígitos                                  | 2020 - 2022        | Não listado       | Não listado                   |
# | id_municipio_estabelecimento   | STRING           | ID Município - IBGE 7 Dígitos                                              | 2020 - 2022        | Não listado       | Não listado                   |
# | id_paciente                    | STRING           | ID Paciente                                                                | 2020 - 2022        | Não listado       | Não listado                   |
# | lote_vacina                    | STRING           | Número do Lote                                                             | 2020 - 2022        | Não listado       | Não listado                   |
# | nacionalidade_paciente         | STRING           | Nacionalidade                                                              | 2020 - 2022        | Não listado       | Não listado                   |
# | nome_fabricante_vacina         | STRING           | Nome do fabricante/fornecedor                                              | 2020 - 2022        | Não listado       | Não listado                   |
# | nome_fantasia_estabelecimento  | STRING           | Nome Fantasia                                                              | 2020 - 2022        | Não listado       | Não listado                   |
# | pais_endereco_paciente         | STRING           | País do Endereço                                                           | 2020 - 2022        | Não listado       | Não listado                   |
# | raca_cor_paciente              | STRING           | Raça ou cor                                                                | 2020 - 2022        | Não listado       | Não listado                   |
# | razao_social_estabelecimento   | STRING           | Razão Social                                                               | 2020 - 2022        | Não listado       | Não listado                   |
# | referencia_fabricante_vacina   | STRING           | CNPJ do fabricante/fornecedor                                              | 2020 - 2022        | Não listado       | Não listado                   |
# | sexo_paciente                  | STRING           | Sexo                                                                       | 2020 - 2022        | Não listado       | Não listado                   |
# | sigla_uf                       | STRING           | Sigla da Unidade da Federação                                              | 2020 - 2022        | Não listado       | Não listado                   |
# | sistema_origem                 | STRING           | Sistema de origem                                                          | 2020 - 2022        | Não listado       | Não listado                   |

# %% [markdown]
# ### Configurando as bibliotecas utilizadas

# %%
import pandas as pd
import basedosdados as bd

# %% [markdown]
# ### Carregando a tabela

# %%
# Recebendo a tabela com as informações dos bens de cada candidato (limitado a 5 mil linhas)
tabela_vacinação = bd.read_table(dataset_id='br_ms_vacinacao_covid19',
                   table_id='microdados',
                   billing_project_id='fauna-381513',
                   limit=10000)
# Out:
# Downloading: 100%|███████████████████████████████████████████| 1258/1258 [00:00<00:00, 2318.05rows/s]

# %% [markdown]
# ### Criando a função de busca

# %%
# Função de busca pelo condidato e
def vacina_brasil(uf, idade, baixar=2):
    
    # Criando um DataFrame filtrando o estado
    tabela_uf = tabela_vacinação[tabela_vacinação['sigla_uf'].str.contains(uf)]
    
    # Criando um DataFrame filtrando pela idade do paciente
    busca = tabela_uf[tabela_uf['idade_paciente'].str.contains(idade)]
    
    # Verificando o tamanha da tabela
    if len(df_busca) == 0:
        print("Algo de errado tente novamente!")
        
    else:
        if baixar != '1' or baixar != '2':
            print('Tente novamente conforme as opções')
        if baixar == '1':
            busca.to_excel(f'pesquisa_{uf}_{idade}.xlsx')
            print("Aquivo foi salvo na pasta 'pesquisas'")
        if baixar == '2':
            return busca

# %%
tabela_vacinação['sigla_uf'].unique()
# Out:
# array(['invertebrados_terrestres', 'anfibios', 'repteis', 'aves',
#        'mamiferos', 'invertebrados_aquaticos', 'peixes'], dtype=object)

# %%
tabela_vacinação['idade_paciente'].unique()
# Out:
# array(['VU', 'EN', 'CR', 'CR (PEX)', 'EX', 'RE', 'EW'], dtype=object)

# %% [markdown]
# ### Pegando as informações com o usuário

# %%
# Recebendo do usuairo as informações para a busca do candidato na base de dados
# E tratando os possiveis erros com o preenchimento das variaveis

estado = input("Informe o estado em anos: ")

idade = int(input("Informe a idade em anos: "))

baixar_busca = input("Deseja baixar a tabela com o resultado da busca? (1 para baixar e 2 para não baixar): ")

# Tratando os possiveis erros da função
vacina_brasil(estado, idade, baixar_busca)
# Out:
# Qual o nome do grupo?: mamiferos
# Qual a categoria de extinção: en
# Deseja baixar a tabela com o resultado da busca? (1 para baixar e 2 para não baixar): 2
# Tente novamente conforme as opções
#          grupo            ordem          familia  \
# 678  mamiferos        Carnivora          Felidae
# 682  mamiferos  Cetartiodactyla       Balaenidae
# 683  mamiferos  Cetartiodactyla  Balaenopteridae
# 685  mamiferos  Cetartiodactyla  Balaenopteridae
# 690  mamiferos  Cetartiodactyla      Delphinidae
# 692  mamiferos  Cetartiodactyla          Iniidae
# 699  mamiferos       Chiroptera   Phyllostomidae
# 701  mamiferos        Cingulata      Dasypodidae
# 709  mamiferos         Primates         Atelidae
# 712  mamiferos         Primates         Atelidae
# 713  mamiferos         Primates         Atelidae
# 715  mamiferos         Primates         Atelidae
# 718  mamiferos         Primates   Callitrichidae
# 719  mamiferos         Primates   Callitrichidae
# ...
